# %%
import requests
import json
import time

# %%
API_KEY = '45d133bd183b4a2c8c36aa55b462b941'

# %%
re=requests.get('https://api.openweathermap.org/data/3.0/onecall/day_summary?lat={lat}&lon={lon}&date={date}&appid={45d133bd183b4a2c8c36aa55b462b941}')

# %%
re.status_code
# Out:
# 401

# %%
fd = re.json()

# %%
fd
# Out:
# {'cod': 401,
#  'message': 'Please note that using One Call 3.0 requires a separate subscription to the One Call by Call plan. Learn more here https://openweathermap.org/price. If you have a valid subscription to the One Call by Call plan, but still receive this error, then please see https://openweathermap.org/faq#error401 for more info.'}

# %%
fd
# Out:
# {'cod': 401,
#  'message': 'Please note that using One Call 3.0 requires a separate subscription to the One Call by Call plan. Learn more here https://openweathermap.org/price. If you have a valid subscription to the One Call by Call plan, but still receive this error, then please see https://openweathermap.org/faq#error401 for more info.'}

# %%
asd = re.text

# %%
json(asd.split())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3443534638.py in <cell line: 0>()
# ----> 1 json(asd.split())
#
# TypeError: 'module' object is not callable

# %%
z

# %%
j= []
d = []
f = []
a = []
l = []
jj = []
for i in fd['Time Series (Daily)']:
  j.append(i)

# %%
k= []

# %%
gh = []

# %%
fd

# %%
for i in fd['Time Series (Daily)']:

  d.append(fd['Time Series (Daily)'][i]['1. open'])

# %%
d

# %%
for i in fd['Time Series (Daily)']:
  f.append(fd['Time Series (Daily)'][i]['2. high'])

# %%
f

# %%
for i in fd['Time Series (Daily)']:
  a.append(fd['Time Series (Daily)'][i]['3. low'])

# %%
a

# %%
for i in fd['Time Series (Daily)']:
  l.append(fd['Time Series (Daily)'][i]['4. close'])

# %%
l

# %%
for i in fd['Time Series (Daily)']:
  gh.append(fd['Time Series (Daily)'][i]['5. volume'])

# %%
jj

# %%
jj

# %%
d

# %%
fd['Time Series (Daily)']['2021-10-14']['1. open']

# %%
type(k)

# %%
import pandas as pd

# %%
d

# %%
f

# %%
allu = a[:2604]

# %%
s= pd.DataFrame({'a':f, 'v':d,'kk': allu, 'kkg':l,'nb':gh,'af':j})

# %%
s

# %%
#extracted content
# !pip install pyodbc

# %%
import pyodbc

# %%
import pyodbc

connection_string = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    r"SERVER=ADITHYA_KALE\MSSQLSERVER02;"
    "DATABASE=weatherdb;"
    "Trusted_Connection=yes;"
)

cnxn = pyodbc.connect(connection_string)
print("Connected!")

# %%
connection_string = (
    "DRIVER={SQL Server};"  # Or another appropriate ODBC driver
    "SERVER=ADITHYA_KALE\\MSSQLSERVER02;"
    "DATABASE=weatherdb;"
    "TrustedConnection = yes;"
)
cnxn = pyodbc.connect(connection_string)
